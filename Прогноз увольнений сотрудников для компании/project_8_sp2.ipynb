# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Александр, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# # Прогноз увольнений сотрудников для компании.
#
# **Описание исследования**
#
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
#
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворенности сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.
#
# Почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
#
# **Цель исследования**
#
# Разработать решение, которое позволит предсказать отток сотрудников из бизнеса для избежания финансовых потерь.
#
# **Задачи исследования**
#
# 1. Построить модель, которая сможет предсказать уровень удовлетворенности сотрудника на основе данных заказчика.
# 2. Построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.
#
# **Описание данных**
#
# - id — уникальный идентификатор сотрудника;
# - dept — отдел, в котором работает сотрудник;
# - level — уровень занимаемой должности;
# - workload — уровень загруженности сотрудника;
# - employment_years — длительность работы в компании (в годах);
# - last_year_promo — показывает, было ли повышение за последний год;
# - last_year_violations — показывает, нарушал ли сотрудник трудовой договор за последний год;
# - supervisor_evaluation — оценка качества работы сотрудника, которую дал руководитель;
# - salary — ежемесячная зарплата сотрудника;
# - job_satisfaction_rate — уровень удовлетворённости сотрудника работой в компании, целевой признак (задача 1)
# - quit — увольнение сотрудника из компании, целевой признак (задача 2)
#
# **Данную задачу будем решать в два этапа:**
#
# 1. Разработаем модель, которая предскажет уровень удовлетворенности сотрудника.
# 2. Разработаем модель, которая предскажет увольнение сотрудника.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %%
#загрузка библиотек
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# !pip install phik -q
import phik
from phik.report import plot_correlation_matrix

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, LabelEncoder

from sklearn.model_selection import RandomizedSearchCV

from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.dummy import DummyRegressor, DummyClassifier

from sklearn.metrics import make_scorer, roc_auc_score

RANDOM_STATE = 42

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# ## Задача 1

# %% [markdown]
# ### Загрузка данных

# %%
train = pd.read_csv('train_job_satisfaction_rate.csv')
test = pd.read_csv('test_features.csv')
test_target = pd.read_csv('test_target_job_satisfaction_rate.csv')

# try except '/datasets/test_target_job_satisfaction_rate.csv'

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Данные загрузили.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных задать индекс-столбец- за это действие отвечает параметр `index_col`.

# %%
train.info()
train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# ...

# %%
test.info()
test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# ...

# %%
test_target.info()
test_target.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %% [markdown]
# Видим разбиение на тренировочную и тестовую выборки в соотношении 2к1.
#
# На первый взгляд в данных проблем нет, названия столбцов имеют правильный вид, ошибок в данных не наблюдаем, данные так же имеют правильный тип.
#
# Единственное в столбцах `dept` и `level` есть пропущенные значения, которые нужно будет чем-то заменить.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Первичный осмотр данных выполнили - отлично!

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Переведем значения столбца `id` в индексы и объеденим в одну таблицу данные из тестовой выборки.

# %%
train = train.set_index('id')
test = test.set_index('id')
test_target = test_target.set_index('id')
test = test.merge(test_target, right_index=True, left_index=True)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Перевод `id` в индекс - отличное решение!

# %%
train.query('dept.isnull() or level.isnull()')
# Out:
#          dept   level workload  employment_years last_year_promo  \
# id
# 631073  sales     NaN   medium                 1              no
# 416327  sales     NaN      low                 1              no
# 694746    NaN  junior   medium                 5              no
# 814624    NaN  junior   medium                 3              no
# 475114    NaN  junior     high                 4              no
# 135043  sales     NaN   medium                 1              no
# 998838  sales     NaN   medium                 1              no
# 497243    NaN  junior   medium                 1              no
# 168668    NaN  junior      low                 3              no
# 641150    NaN  junior      low                 3              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 631073                   no                      4   27600
# 416327                   no                      5   18000
# 694746                   no                      4   21600
# ...

# %%
test.query('dept.isnull() or level.isnull()')
# Out:
#          dept   level workload  employment_years last_year_promo  \
# id
# 609865    NaN  junior   medium                 1              no
# 471990  sales     NaN      low                 1              no
# 832342    NaN  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 609865                   no                      1   20400
# 471990                   no                      3   12000
# 832342                   no                      4   28800
#
#         job_satisfaction_rate
# id
# 609865                   0.12
# 471990                   0.17
# 832342                   0.61

# %% [markdown]
# Убеждаемся в наличии пропущенных значений и видим конкретные строки, которые их имеют. Мы заменим эти пропуски немного ниже.

# %%
test['dept'].unique()
# Out:
# array(['marketing', 'hr', 'sales', 'purchasing', 'technology', nan, ' '],
#       dtype=object)

# %%
test['dept'] = test['dept'].replace(' ', np.nan)

# %%
test['workload'].unique()
# Out:
# array(['medium', 'low', 'high', ' '], dtype=object)

# %%
test['workload'] = test['workload'].replace(' ', np.nan)

# %% [markdown]
# В тестовых данных в столбцах `dept` и `workload` были пустые значения, которые мы заменили на `NaN`, в дальнейшей мы заменим эти пропущенные значения.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Найдены аномалии в `test` - отлично!

# %%
ohe_columns = ['last_year_promo', 'last_year_violations', 'dept']
ord_columns = ['level', 'workload']

ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))]) 

ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))])

# %% [markdown]
# Создали Pipeline для замены пропущенных значений в столбцах dept, level и workload наиболее встречаемыми позициями методом SimpleImputer. Эти Pipeline будуем использовать на следующих шагах при построении модели.

# %% [markdown]
# ### Исследовательский анализ данных

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,15))
print('Тренировочные данные'.center(100))
train.pivot_table(index='dept', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Отдел', ylabel='', ax=axes[0]);

train.pivot_table(index='level', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Уровень должности', ylabel='', ax=axes[1]);

train.pivot_table(index='workload', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Загруженность', ylabel='', ax=axes[2]);

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,10))
train.pivot_table(index='last_year_promo', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Повышение за последний год', ylabel='', ax=axes[0]);

train.pivot_table(index='last_year_violations', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Нарушения за последний год', ylabel='', ax=axes[1]);
# Out:
#                                         Тренировочные данные

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,15))
print('Тестовые данные'.center(100))
test.pivot_table(index='dept', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Отдел', ylabel='', ax=axes[0]);

test.pivot_table(index='level', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Уровень должности', ylabel='', ax=axes[1]);

test.pivot_table(index='workload', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Загруженность', ylabel='', ax=axes[2]);

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,10))
test.pivot_table(index='last_year_promo', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Повышение за последний год', ylabel='', ax=axes[0]);

test.pivot_table(index='last_year_violations', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Нарушения за последний год', ylabel='', ax=axes[1]);
# Out:
#                                           Тестовые данные

# %% [markdown]
# Видим корректное разбиение данных на тренировочную и тестовую выборки. Больше всего сотрудников работает в отделе продаж. Мало сотрудников получали повышения за последний год.
#
# Уровень должности и загруженность можно будет ранжировать при кодировании, остальные данные для ранжирования не подходят.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
fig.suptitle('Тренировочные данные', fontsize=14)
#sns.histplot(train['employment_years'], bins=10, ax=axes[0]).set_title('Количество лет работы')
#sns.histplot(train['supervisor_evaluation'], ax=axes[1]).set_title('Оценка качества работы')
#plt.xticks(np.arange(min(train['supervisor_evaluation']), max(train['supervisor_evaluation'])+1, 1.0))

sns.countplot(train['employment_years'], ax=axes[0]).set_title('Количество лет работы')
sns.countplot(train['supervisor_evaluation'], ax=axes[1]).set_title('Оценка качества работы')

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
sns.histplot(train['salary'], ax=axes[0]).set_title(
    'Зарплата, руб.')
sns.histplot(train['job_satisfaction_rate'], ax=axes[1]).set_title(
    'Уровень удовлетворенности работой');

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> `employment_years` и `supervisor_evaluation` - дискретные признаки, для их анализа нужнен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать `sns.countplot` или `plot(kind='bar')`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Понял свою ошибку, воспользовался `sns.countplot` и исправил графики.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Учтено.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
fig.suptitle('Тестовые данные', fontsize=14)

#sns.histplot(test['employment_years'], bins=10, ax=axes[0]).set_title('Количество лет работы')
#sns.histplot(test['supervisor_evaluation'], bins=5, ax=axes[1]).set_title('Оценка качества работы')
#plt.xticks(np.arange(min(test['supervisor_evaluation']), max(test['supervisor_evaluation'])+1, 1.0))

sns.countplot(test['employment_years'], ax=axes[0]).set_title('Количество лет работы')
sns.countplot(test['supervisor_evaluation'], ax=axes[1]).set_title('Оценка качества работы')

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
sns.histplot(test['salary'], ax=axes[0]).set_title(
    'Зарплата, руб.')
sns.histplot(test['job_satisfaction_rate'], ax=axes[1]).set_title(
    'Уровень удовлетворенности работой');

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
fig.suptitle('Тренировочные данные', fontsize=14)
sns.boxplot(x=train['employment_years'], ax=axes[0]).set_title(
    'Количество лет работы')
sns.boxplot(x=train['supervisor_evaluation'], ax=axes[1]).set_title(
    'Оценка качества работы')

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
sns.boxplot(x=train['salary'], ax=axes[0]).set_title(
    'Зарплата, руб.')
sns.boxplot(x=train['job_satisfaction_rate'], ax=axes[1]).set_title(
    'Уровень удовлетворенности работой');

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
fig.suptitle('Тестовые данные', fontsize=14)
sns.boxplot(x=test['employment_years'], ax=axes[0]).set_title(
    'Количество лет работы')
sns.boxplot(x=test['supervisor_evaluation'], ax=axes[1]).set_title(
    'Оценка качества работы')

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
sns.boxplot(x=test['salary'], ax=axes[0]).set_title(
    'Зарплата, руб.')
sns.boxplot(x=test['job_satisfaction_rate'], ax=axes[1]).set_title(
    'Уровень удовлетворенности работой');

# %% [markdown]
# Количиственные переменные также имеют схожие значения для тренировочных и тестовых данных.
#
# В основном сотрудники работают от 2 до 6 лет, зарплата в среднем имеет значение около 30 тысяч рублей. В целом сотрудников устраивает их работа, их начальство также считает их работу приемлимой.
#
# Есть малое количество сотрудников, которые по мнению начальства очень плохо выполняют свою работу. И есть небольшая часть сотрудников которые получают свыше 80 тысяч рублей.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Выполнен EDA данных, прокомментированы выбросы.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Нет анализа корреляции.
#
# Напомню, что матрица корреляций Пирсона не подходит для анализа датасетов, в которых присутствуют категориальные или дискретные признаки - по ним корреляций Пирсона не может быть оценена вообще (в случае категориальных) или не может быть оценена корректно (в случае дискретных).
#
# Хорошим решением будет использование матрицы `phik` - она анализирует корреляцию между признаками любого типа и не требует предварительного кодирования. При использовании `phik` крайне важно настроить параметр `interval_cols`, передав ему список с названиями непрерывных признаков: если этого не сделать, библиотека своими силами будет пытаться разнести признаки по типам, и она часто делает в этом ошибки - от этого в свою очередь мы получаем некорректную оценку корреляций, так как от типа признака зависит метод оценки корреляции.
#
# Познакомиться с этой корреляцией можно тут: на английском: https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7, на русском: https://dzen.ru/a/ZEtcuc4K2RX_Jstr?utm_referer=www.google.com.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Учтено.

# %%
phik_overview=train.phik_matrix(interval_cols=['salary', 'job_satisfaction_rate']);
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title='Матрица корреляций признаков тренировочной выборки',
    fontsize_factor=1.1,
    figsize=(12, 8))

phik_overview=test.phik_matrix(interval_cols=['salary', 'job_satisfaction_rate']);
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title='Матрица корреляций признаков тестовой выборки',
    fontsize_factor=1.1,
    figsize=(12, 8))

# %% [markdown]
# Матрицы корреляций для тренировочных и тестовых данных имеют схожие значения.
#
# Есть сильная связь между загруженностью сотрудника и его заработной платой, и между уровнем должности и заработной платой.
#
# Так же есть связь между длительностью работы и уровнем занимаемой должности.
#
# Мультиколлинеарность отсутствует.
#
# Уровень удовлетворенности сотрудника зависит от оценки его качества работы и от имеющихся нарушений трудового договора.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Добавил анализ корреляции
# </div>

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Перед моделированием нужно проверить наличие новых дубликатов в данных: так как мы удалили часть лишних признаков (перевели `id` в индекс), у нас могут появиться новые явные дубликаты: чем меньше признаков остаётся, тем выше шанс, что значения остальных признаков будут пересекаться. При этом ценности для модели такие наблюдения уже не принесут, поэтому стоит проверить дубликаты также в финальной версии таблицы.
#
# При этом важно проверить только `train`: наличие дубликатов в `test` нам никак не мешает, но это правильное решение с точки зрения неприкосновенности `test`, ведь реальный поток данных (который имитирует `test` выборка) мы исправить не сможем. А вот наличие дубликатов в `train` не только не принесёт пользы модели, но может и навредить.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Учтено.

# %%
print(train.shape)
train[train.duplicated()]
# Out:
# (4000, 9)
#               dept   level workload  employment_years last_year_promo  \
# id
# 302957  purchasing  junior      low                 1              no
# 752399       sales  middle      low                 7              no
# 802286       sales  junior   medium                 1              no
# 167303       sales  junior   medium                 1              no
# 191841       sales  junior   medium                 1              no
# ...            ...     ...      ...               ...             ...
# 737303       sales  middle   medium                 3              no
# 281204  technology  junior      low                 2              no
# 261436       sales  middle      low                 3              no
# 457950  technology  junior     high                 2              no
# 957499       sales  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# ...

# %% [markdown]
# После убирания столбца id в данных появились явные дубликаты. Избавимся от них:

# %%
train = train.drop_duplicates()
train.shape
# Out:
# (3755, 9)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Избавился от появившихся явных дубликатов.
# </div>

# %% [markdown]
# Разделим данные на X_train, X_test, y_train, y_test.
#
# Разобьем наши данные на категориальные и количественные, при этом столбцы `level` и `workload` будем кодировать с помощью OrdinalEncoder.

# %%
X_train = train.drop(['job_satisfaction_rate'], axis=1)
X_test = test.drop(['job_satisfaction_rate'], axis=1)
y_train = train['job_satisfaction_rate']
y_test = test['job_satisfaction_rate']

ohe_columns = ['last_year_promo', 'last_year_violations', 'dept']
ord_columns = ['level', 'workload']
num_columns = ['employment_years', 'supervisor_evaluation', 'salary']

ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
        ('ohe', OneHotEncoder(drop='first', handle_unknown='error', sparse=False))]) 

ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'sinior'], 
                    ['low', 'medium', 'high'],
                ], 
         handle_unknown='use_encoded_value', unknown_value=np.nan)),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))]) 

data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
) 

pipe_final = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', DecisionTreeRegressor(random_state=RANDOM_STATE))
    ]
)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Здорово, что используешь сочетание `ColumnTransformer` и `Pipeline` для соединения разных инструментов в единый модельный объект и настраиваешь бесперебойную работу энкодера в случае появления в данных новых, неизвестных на момент обучения значений признаков - так твоё решение будет более гибким и масштабируемым.

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# Для проверки качества модели будем использовать метрику SMAPE, для ее нахождения напишем функцию. Нашим критерием успеха будет значение метрики ≤ 15 на тестовой выборке.

# %%
def smape(y_test, y_pred):
    num = np.abs(y_test-y_pred)
    den = (np.abs(y_test) + np.abs(y_pred)) / 2
    func = num / den
    return np.mean(func) * 100

smape_scorer = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть функция для оценки `sMAPE`, а также пользовательский скорринг для кросс-валидации - супер!
# </div>

# %%
param_distributions = [
    { 
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)], 
        'models__max_depth': range(1,5), 
#        'models__min_samples_split' : range(1,5), 
#        'models__min_samples_leaf': range(1,5), 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    }, 
     
    { 
        'models': [LinearRegression()], 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    }, 
    
     { 
        'models': [KNeighborsRegressor()], 
        'models__n_neighbors': range(1, 5), 
        'models__weights': ['uniform', 'distance'], 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'] 
    }   
]

randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_distributions=param_distributions, 
    scoring=smape_scorer, 
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train, y_train) 
y_test_pred = randomized_search.predict(X_test)

print('Метрика smape для лучшей модели:\n', np.abs(randomized_search.best_score_))
print('\nЛучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
# Out:
# Метрика smape для лучшей модели:
#  16.367042495973617
#
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse=False))]),
#                                                   ['last_year_promo',
#                                                    'last_year_violations',
#                                                    'dept']),
#                                                  ('ord',
# ...

# %%
pd.DataFrame(randomized_search.cv_results_)[['param_models','mean_test_score']].sort_values(by='mean_test_score', ascending=False)
# Out:
#                                         param_models  mean_test_score
# 1  KNeighborsRegressor(n_neighbors=4, weights='di...       -16.367042
# 4  KNeighborsRegressor(n_neighbors=4, weights='di...       -16.527886
# 8  KNeighborsRegressor(n_neighbors=4, weights='di...       -17.069863
# 7  KNeighborsRegressor(n_neighbors=4, weights='di...       -17.315875
# 0  KNeighborsRegressor(n_neighbors=4, weights='di...       -17.428770
# 9  KNeighborsRegressor(n_neighbors=4, weights='di...       -19.087762
# 5  KNeighborsRegressor(n_neighbors=4, weights='di...       -20.785064
# 6             DecisionTreeRegressor(random_state=42)       -22.691739
# 2             DecisionTreeRegressor(random_state=42)       -23.965105
# 3                                 LinearRegression()       -25.005621

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `RandomizedSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание, что оценка получена на кросс-валидации, а не на `train` выборке - очень важно корректно разделять эти сущности.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Как видишь, твоя метрика имеет отрицательное значение - это особеность работы `make_scorer` с настроенным параметром `greater_is_better=False`: так как метрика `sMAPE` применяется для задач регрессии, то она тем лучше, чем ниже - это нужно учитывать при создании скорринга для кросс-валидации, так как по умолчанию инструменты подбора гиперпараметров и поиска лучшей модели вроде `GridSearchCV` умеют только максимизировать метрику качества. Поэтому при создании скорринга с помощью `make_scorer` важно настроить параметр `greater_is_better=False`, чтобы оптимизируемая метрика минимизировалась, а не максимизировалась - таким образом задача максимизации будет решаться через задачу минимизации обратной функции.
#
# Поэтому при выводе метрики на экран её стоит сделать положительной: взять по модулю, домножить на `-1` или просто указать `-` при выводе на экран, вроде `print(-a)`.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Взял результат метрики в  `print` по модулю.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Учтено.

# %%
print(f'Метрика smape на тестовой выборке: {smape(y_test, y_test_pred)}')
# Out:
# Метрика smape на тестовой выборке: 14.427109405947364

# %%
# !pip install shap -q
import shap

# %%
pipe_cat = randomized_search.best_estimator_['preprocessor'].transformers[0][1] #Вытаскиваем кодирование
pipe_ord = randomized_search.best_estimator_['preprocessor'].transformers[1][1] #Вытаскиваем масштабирование
pipe_num = randomized_search.best_estimator_['preprocessor'].transformers[2][1]
data_cat = pd.DataFrame(pipe_cat.fit_transform(X_train[ohe_columns]), columns = pipe_cat[1].get_feature_names())
data_ord = pd.DataFrame(pipe_ord.fit_transform(X_train[ord_columns]), columns = ord_columns)
data_num = pd.DataFrame(pipe_num.fit_transform(X_train[num_columns]), columns = num_columns)
X_shap = pd.concat([data_cat, data_num], axis=1)
X_shap = pd.concat([X_shap, data_ord], axis=1)

# %%
explainer = shap.Explainer(randomized_search.best_estimator_['models'].predict, X_shap)

shap_values = explainer(X_shap[:5])
shap.plots.beeswarm(shap_values, max_display=18, show=False)
plt.title('График SHAP значений')
plt.ylabel('Значения SHAP')
plt.show()

# %% [markdown]
# Лучшей моделью стала KNeighborsRegressor с параметрами n_neighbors=4 и weights='distance'. При этом лучшим методом масштабирования стал StandardScaler. Метрика smape на тестовых данных показала хороший результат с 14.42 < 15.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Лучшую модель оценили на `test` - отличный результат!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Очень важно также проверить лучшую модель на адекватность, сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать `DummyRegressor` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на `train`, делает нашу работу лучше.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Учтено.

# %%
pipe_dummy = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DummyRegressor())])

pipe_dummy.fit(X_train, y_train) 

dummy_pred = pipe_dummy.predict(X_test)
print(f'Метрика smape на тестовой выборке: {smape(y_test, dummy_pred)}')
# Out:
# Метрика smape на тестовой выборке: 38.26225790202237

# %% [markdown]
# Проверили результат метрики на константной моделе. Видим что результат метрики найденной модели гораздо лучше, чем результат константной модели.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Проверил резльтут с помощью модели `DummyRegressor()`
# </div>

# %% [markdown]
# ### Выводы
# Мы выбирали среди 3 моделей с различными гиперпараметрами. Для нашей задачи лучшей моделью стала KNeighborsRegressor, которая учитывает 4 ближайших соседей, и каждая точка имеет различные веса в зависимости от расстояния.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Небольшой промежуточный вывод - отлично! Полезно было бы также описать метрику на кросс-валидации каждой модели, чтобы наглядно было понятно, из каких моделей выбирали лучшую.

# %% [markdown]
# ## Задача 2

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# В этой задаче по аналогичным шагам из предыдущей задачи аналогичные замечания.

# %% [markdown]
# ### Загрузка данных

# %%
train2 = pd.read_csv('train_quit.csv')
test2 = pd.read_csv('test_features.csv')
test_target2 = pd.read_csv('test_target_quit.csv')

# %%
train2.info()
train2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# ...

# %%
test2.info()
test2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# ...

# %%
test_target2.info()
test_target2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes

# %% [markdown]
# В новых тренировочных данных ошибок нету, все значения имеют правильный тип. Нужно будет снова исправить пропуски в тестовых данных и перевести значения целевого признака в 0,1.

# %% [markdown]
# ### Предобработка данных

# %%
train2 = train2.set_index('id')
test2 = test2.set_index('id')
test_target2 = test_target2.set_index('id')
test2 = test2.merge(test_target2, right_index=True, left_index=True)

# %% [markdown]
# Перевели значения столбца id в индексы и объеденили в одну таблицу данные из тестовой выборки.

# %%
#train2['quit'] = train2['quit'].replace({'no': 0, 'yes': 1})
#test2['quit'] = test2['quit'].replace({'no': 0, 'yes': 1})
lab = LabelEncoder()
train2['quit'] = lab.fit_transform(train2['quit'])
test2['quit'] = lab.transform(test2['quit'])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Кодирование нельзя делать руками:
# - при появлении новых значений категориальных признаков, не предусмотренных твоим решением, модель или упадёт, или будет генерировать ошибки;
# - такое решение не сделаешь частью `pipeline`, а все современные решения базируются на них.
#
# Поэтому кодирование нужно делать только с применением обучаемых трансформеров. Для кодирования целевого признака нужно использовать `LabelEncoder` (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html#:~:text=Encode%20target%20labels%20with%20value%20between%200%20and%20n_classes%2D1.).

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Выполнил кодирование целевого признака с помощью `LabelEncoder`
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Учтено.

# %%
test2['dept'] = test2['dept'].replace(' ', np.nan)
test2['workload'] = test2['workload'].replace(' ', np.nan)

# %% [markdown]
# Вместо пустых значений сделали NaN.

# %%
ohe_columns2 = ['last_year_promo', 'last_year_violations', 'dept']
ord_columns2 = ['level', 'workload']

ohe_pipe2 = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))]) 

ord_pipe2 = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))])

# %% [markdown]
# Подготовили Pipeline для заполнения пропущеных значений наиболее встречаемыми.

# %% [markdown]
# ### Исследовательский анализ данных

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,15))
print('Тренировочные данные'.center(100))
train2.pivot_table(index='dept', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Отдел', ylabel='', ax=axes[0]);

train2.pivot_table(index='level', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Уровень должности', ylabel='', ax=axes[1]);

train2.pivot_table(index='workload', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Загруженность', ylabel='', ax=axes[2]);

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,15))
train2.pivot_table(index='last_year_promo', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Повышение за последний год', ylabel='', ax=axes[0]);

train2.pivot_table(index='last_year_violations', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Нарушения за последний год', ylabel='', ax=axes[1]);

train2.pivot_table(index='quit', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Увольнения', ylabel='', ax=axes[2]);

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,5))


#sns.histplot(train2['employment_years'], bins=10, ax=axes[0]).set_title('Количество лет работы')
#sns.histplot(train2['supervisor_evaluation'], bins=5, ax=axes[1]).set_title('Оценка качества работы')
#plt.xticks(np.arange(min(train['supervisor_evaluation']), max(train['supervisor_evaluation'])+1, 1.0))

sns.countplot(train2['employment_years'], ax=axes[0]).set_title('Количество лет работы')
sns.countplot(train2['supervisor_evaluation'], ax=axes[1]).set_title('Оценка качества работы')

sns.histplot(train2['salary'], ax=axes[2]).set_title('Зарплата, руб.')

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,5))
sns.boxplot(x=train2['employment_years'], ax=axes[0]).set_title(
    'Количество лет работы')
sns.boxplot(x=train2['supervisor_evaluation'], ax=axes[1]).set_title(
    'Оценка качества работы')
sns.boxplot(x=train2['salary'], ax=axes[2]).set_title('Зарплата, руб.');
# Out:
#                                         Тренировочные данные

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не исправлена визуализация дискретных признаков.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента v.2 <a class="tocSkip"> </h2>
#
# Упустил этот момент. Сейчас исправил графики для дискретных признаков.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Учтено.

# %% [markdown]
# Новые тренировочные данные совпадают по значениям с рассмотренными нами ранее.
#
# Можем наблюдать, что 28% сотрудников увольняется из компании, рассмотрим какие показатели влияют на их увольнения.

# %% [markdown]
# Узнаем в каком отделе с большей вероятностью работает уволившийся сотрудник и какой у него уровень загруженности. Также сравним средние значение зарплаты ушедших сотрудников с теми, кто остался в компании.

# %%
quit_yes = train2.query('quit == 1') #ушли
quit_no = train2.query('quit == 0') #остались

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20,20))
quit_yes.pivot_table(index='dept', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Отдел уволившихся', ylabel='', ax=axes[0]);
quit_no.pivot_table(index='dept', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Отдел оставшихся', ylabel='', ax=axes[1]);

quit_yes.pivot_table(index='workload', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Загруженность уволившихся', ylabel='', ax=axes[2]);
quit_no.pivot_table(index='workload', values='salary', aggfunc='count').plot(
    kind='pie', y='salary', legend=False, autopct = '%1.0f%%', 
    title = 'Загруженность оставшихся', ylabel='', ax=axes[3]);

print(f'Средний уровень зарплаты Уволившихся сотрудников: {round(quit_yes["salary"].mean(),0)} рублей')
print(f'Средний уровень зарплаты Сотрудников оставшихся в компании: {round(quit_no["salary"].mean(),0)} рублей')
# Out:
# Средний уровень зарплаты Уволившихся сотрудников: 23885.0 рублей
# Средний уровень зарплаты Сотрудников оставшихся в компании: 37702.0 рублей

# %% [markdown]
# Причина увольнения не зависит от того в каком отделе работает сотрудник. На причину увольнения влияет низкая зарплата, которая скорее всего связана с малым количеством задач, которые стоят перед сотрудником. Оставшиеся сотрудники как правило имеют среднюю загруженность, у тех кто уволился загруженность находилась между низкой и средней.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть анализ портрета клиента - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# 1. Анализ должен быть либо выполнен по всем признакам, либо должно быть хорошее обоснование, почему именно этот набор признаков лучше всего описывает портрет клиента.
#
# 2. Анализ нужно сделать с помощью относительных величин - оперировать абсолютными величинами не всегда удобно, так как в зависимости от масштаба исследования (компания на 100 человек и компания на 100 000 человек, например) результаты могут быть более или менее интерпретируемыми. Для категориальных/дискретных признаков мы можем использовать `value_counts(normalize=True)`, для непрерывных также стоит посчитать и сравнить средние.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
phik_overview=train2.phik_matrix(interval_cols=['salary']);
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title='Матрица корреляций признаков',
    fontsize_factor=1.1,
    figsize=(12, 8))

# %%
phik_overview=quit_yes.phik_matrix(interval_cols=['salary']);
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title='Матрица корреляций признаков уволившихся',
    fontsize_factor=1.1,
    figsize=(12, 8))

phik_overview=quit_no.phik_matrix(interval_cols=['salary']);
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title='Матрица корреляций признаков оставшихся',
    fontsize_factor=1.1,
    figsize=(12, 8))

# %% [markdown]
# Матрицы корреляций для обоих классов целевого признака имеют схожий вид. Мультиколлинеарность отсутствует.
#
# Видим среднюю связь между увольнениями и заработной платой, и количеством лет работы.
#
# Так же есть связь между длительностью работы и уровнем занимаемой должности.
#
# Есть сильная связь между загруженностью сотрудника и его заработной платой, и между уровнем должности и заработной платой.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Добавил анализ корреляции.
# </div>

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20,5))
quit_yes['employment_years'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Количество лет',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Лет работы уволившихся', ax=axes[0])
quit_no['employment_years'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Количество лет',
                                                                   ylabel = 'Частота',
                                                                   title = 'Лет работы оставшихся', ax=axes[1])

quit_yes['supervisor_evaluation'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Оценка',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Оценка работы уволившихся', ax=axes[2])
quit_no['supervisor_evaluation'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Оценка',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Оценка работы оставшихся', ax=axes[3])

fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20,5))
quit_yes['dept'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Отдел',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Отдел уволившихся', ax=axes[0])
quit_no['dept'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Отдел',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Отдел оставшихся', ax=axes[1])

quit_yes['level'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Уровень',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Уровень должности уволившихся', ax=axes[2])
quit_no['level'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Уровень',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Уровень должности оставшихся', ax=axes[3])

fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20,5))

quit_yes['workload'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Загруженность',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Загруженность уволившихся', ax=axes[0])
quit_no['workload'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Загруженность',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Загруженность оставшихся', ax=axes[1])

quit_yes['last_year_promo'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Повышение',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Повышения уволившихся', ax=axes[2])
quit_no['last_year_promo'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Повышение',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Повышения оставшихся', ax=axes[3])

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
quit_yes['last_year_violations'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Нарушение',
                                                                   ylabel = 'Частота', 
                                                                   title = 'Нарушения уволившихся', ax=axes[0])

quit_no['last_year_violations'].value_counts(normalize=True).plot(kind='bar', 
                                                                   xlabel = 'Нарушение', 
                                                                   ylabel = 'Частота', 
                                                                   title = 'Нарушения оставшихся', ax=axes[1])

print(f'Средний уровень зарплаты Уволившихся сотрудников: {round(quit_yes["salary"].mean(),0)} рублей')
print(f'Средний уровень зарплаты Сотрудников оставшихся в компании: {round(quit_no["salary"].mean(),0)} рублей')
# Out:
# Средний уровень зарплаты Уволившихся сотрудников: 23885.0 рублей
# Средний уровень зарплаты Сотрудников оставшихся в компании: 37702.0 рублей

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> На графиках не подписаны оси.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента v.2 <a class="tocSkip"> </h2>
#
# Не обратил внимания. Сейчас подписал обе оси.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Учтено.

# %% [markdown]
# Обычно сотрудники уволняются спустя 1год работы и имея должность Junior. Оценка работы уволившихся 3, ниже чем у тех кто остался - 4. Уволившиеся имели низкую либо среднюю загруженость, тогда как оставшиеся имели среднюю загруженность.
# Уволившиеся не получали повышения, из оставишхся были сотрудники с повышением.
#
# Отдел, как и нарушения, никак не влияют на причину увольнения.
#
# Уровень зарплаты у уволившихся 24 тысячи, меньше чем у оставшихся 38 тысяч.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Рассмотрел нормализованные данные, для непрерывной величины зарпалаты сравнил средние значения.
# </div>

# %% [markdown]
# Визуализируем и сравним распределения признака `job_satisfaction_rate` для ушедших и оставшихся сотрудников. Для этого объеденим два целевых признака в одну таблицу.

# %% [markdown]
# Как можем наблюдать, уровень удовлетворенности сотрудника работой в компании влияет на то, уволится ли  этот сотрудник. Большинство уволившихся сотрудников имеют уровень удовлетворенности меньше 0.5.
#
# Мы опять убеждаемся что отдел мало влияет на причину увольнения. В основном сотрудники увольняются с уровнем Junior, проработав меньше 2 лет, не получившие повышения и имеющие малую заработную плату в районе 20 тысяч рублей.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Тут нужно исследовать только разницу между удовлетворённостью и уходом - остальные признаки нас не интересуют. При этом диаграмма рассеяния как инструмент анализа распределений не подходит - тесноту связи мы оценим с помощью корреляции.
#
# Здесь мы имеем дело с непрерывной величиной - для анализа её распределения стоит использовать нормированную гистограмму (например, `shs.histplot()` с параметрами `stat='density', common_norm=False` или `sns.kdeplot()`): гистограммы такого типа позволяют нивелировать разницу в размерах выборок при анализе распределений. Обрати также внимание, что при использовании нормированных гистограмм по оси Y будет уже не частота значений, а плотность распределения.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Визуализируем и сравним распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Используем данные с обоими целевыми признаками тестовой выборки.

# %%
rate_quit = test.merge(test2['quit'], right_index=True, left_index=True)
rate_quit_yes = rate_quit.query('quit == 1') #ушли
rate_quit_no = rate_quit.query('quit == 0') #остались

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,8))
sns.histplot(rate_quit_yes['job_satisfaction_rate'], stat='density', common_norm=False, ax=axes[0]).set_title(
    'Уровень удовлетворённости ушедших')
sns.histplot(rate_quit_no['job_satisfaction_rate'], stat='density', common_norm=False, ax=axes[1]).set_title(
    'Уровень удовлетворённости оставшихся');

# %% [markdown]
# В целом уровень удовлетворённости ушедших сотрудников меньше 0.5. Когда уровень удовлетворённости оставшихся наоборот больше 0.5. Видим конкретную связь между уровнем удовлетворенности и увольнения сотрудника.

# %%
phik_overview=rate_quit.phik_matrix(interval_cols=['salary', 'job_satisfaction_rate']);
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title='Матрица корреляций признаков',
    fontsize_factor=1.1,
    figsize=(12, 8))

phik_overview=rate_quit_yes.phik_matrix(interval_cols=['salary', 'job_satisfaction_rate']);
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title='Матрица корреляций признаков уволившихся',
    fontsize_factor=1.1,
    figsize=(12, 8))

phik_overview=rate_quit_no.phik_matrix(interval_cols=['salary', 'job_satisfaction_rate']);
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title='Матрица корреляций признаков оставшихся',
    fontsize_factor=1.1,
    figsize=(12, 8))

# %% [markdown]
# Значение корреляции между уровнем должности и увольнением имеет хорошее значение, которое не мешает для добавление его как нового входного признака. Остальные признаки не изменили свои значения корреляций.
#
# Мультиколлинеарность отсутствует.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Сравнил нормированные гистограммы для ушедших и оставшихся сотрудников. И добавил матрицу корреляций.
# </div>

# %% [markdown]
# ### Добавление нового входного признака

# %%
print(train2.shape)
train2[train2.duplicated()]
# Out:
# (4000, 9)
#               dept   level workload  employment_years last_year_promo  \
# id
# 873412  technology  junior   medium                 2              no
# 749683       sales  middle      low                 8              no
# 689526   marketing  middle      low                 6              no
# 786443  purchasing  middle      low                 6              no
# 362060       sales  junior      low                 1              no
# ...            ...     ...      ...               ...             ...
# 632886       sales  junior      low                 3              no
# 387733   marketing  middle   medium                 5              no
# 588809       sales  junior   medium                 4              no
# 672059       sales  middle     high                 9              no
# 853842       sales  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary  quit
# id
# ...

# %% [markdown]
# После убирания столбца id в данных появились явные дубликаты. Избавимся от них:

# %%
train2 = train2.drop_duplicates()
train2.shape
# Out:
# (2587, 9)

# %% [markdown]
# Как мы уже убедились `job_satisfaction_rate` и `quit` действительно связаны. Теперь добавим `job_satisfaction_rate`, предсказанный лучшей моделью первой задачи, к входным признакам второй задачи.

# %%
#разбили данные на X_train, y_train, X_test, y_test
X_train2 = train2.drop(['quit'], axis=1)
X_test2 = test2.drop(['quit'], axis=1)
y_train2 = train2['quit']
y_test2 = test2['quit']

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Аналогично нужно проверить дубликаты в `train`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Проверил и избавился от явных дубликатов.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
X_train2['job_satisfaction_rate'] = randomized_search.predict(X_train2)
X_test2['job_satisfaction_rate'] = randomized_search.predict(X_test2)

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ввели новый признак в виде предсказания модели с прошлого этапа.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Аналогично нужно сделать для `test`: реальое значение `job_satisfaction_rate` из прошлой задачи для `test` можно использовать только для анализа.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Сделал добавление также и для test
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Подготовка данных
# Подготовим признаки так же, как и в первой задаче. При этом во входных данных добавился новый количественный признак `job_satisfaction_rate`. Также из входных данных уберем значение отдела `dept`, из-за полного отсутствия связи с целевым признаком.

# %%
X_train2 = X_train2.drop(['dept'], axis=1)
X_test2 = X_test2.drop(['dept'], axis=1)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# После анализа коллинеарности избавился от столбца dept из входных данных.
# </div>

# %%
ohe_columns2 = ['last_year_promo', 'last_year_violations']#, 'dept']
ord_columns2 = ['level', 'workload']
num_columns2 = ['employment_years', 'supervisor_evaluation', 'salary', 'job_satisfaction_rate']

ohe_pipe2 = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
        ('ohe', OneHotEncoder(drop='first', handle_unknown='error', sparse=False))]) 

ord_pipe2 = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'sinior'], 
                    ['low', 'medium', 'high'],
                ], 
         handle_unknown='use_encoded_value', unknown_value=np.nan)),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))]) 

data_preprocessor2 = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns2),
        ('ord', ord_pipe, ord_columns2),
        ('num', StandardScaler(), num_columns2)
    ], 
    remainder='passthrough'
) 

pipe_final2 = Pipeline(
    [
        ('preprocessor', data_preprocessor2),
        ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
    ]
)

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# Значения целового признака имеют сильный дисбаланс 72% на 28%, поэтому для проверки модели будем использовать метрику ROC-AUC. Нашим критерием успеха будет значение метрики ≥0.91 на тестовой выборке.

# %%
param_distributions2 = [
    { 
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)], 
        'models__max_depth': range(1,5), 
        'models__min_samples_leaf': range(1,5), 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    }, 
     
    { 
        'models': [LogisticRegression(random_state=RANDOM_STATE)], 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    }
]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# У `LogisticRegression` не задан `random_state`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Добавил параметр random_state
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
randomized_search2 = RandomizedSearchCV(
    pipe_final2, 
    param_distributions=param_distributions2, 
    scoring='roc_auc', 
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search2.fit(X_train2, y_train2) 

y_test_pred2 = randomized_search2.predict_proba(X_test2)[:, 1]

print('Метрика ROC-AUC для лучшей модели:\n', randomized_search2.best_score_)
print('\nЛучшая модель и её параметры:\n\n', randomized_search2.best_estimator_)
# Out:
# Метрика ROC-AUC для лучшей модели:
#  0.898873930568497
#
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse=False))]),
#                                                   ['last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выбрали лучшую модель.

# %%
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test2, y_test_pred2)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.9104202473379561

# %% [markdown]
# Метрика ROC-AUC на тестовой выборке показала хорошее значение 0.9104 > 0.91. Лучшей моделью стала DecisionTreeClassifier.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный результат работы модели.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Аналогично стоит выполнить оценку модели на адеватность - в случае задачи классификации мы можем использовать  `DummyClassifier` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html#sklearn.dummy.DummyClassifier).

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
pipe_dummy2 = Pipeline([
    ('preprocessor', data_preprocessor2),
    ('models', DummyClassifier())])

pipe_dummy2.fit(X_train2, y_train2) 

dummy_pred2 = pipe_dummy2.predict_proba(X_test2)[:, 1]
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test2, dummy_pred2)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.5

# %% [markdown]
# Проверили результат метрики на константной моделе. Видим что результат метрики найденной модели гораздо лучше, чем результат константной модели.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Сравнил результат метрики с константной моделью
# </div>

# %% [markdown]
# ### Выводы

# %% [markdown]
# Мы выбирали среди 3 моделей с различными гиперпараметрами. Лучшей стала DecisionTreeClassifier с параметрами max_depth=4 ~min_samples_leaf=4~. При этом лучшим методом масштабирования стал ~MinMaxScaler~ StandardScaler. Метрика ROC-AUC на тестовой выборке показала хорошее значение 0.9104 > 0.91.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть небольшой вывод - отлично!

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников.
#
# Компания предоставила данные с характеристиками сотрудников компании. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
#
# Мы разработали решение, которое позволит предсказать отток сотрудников из бизнеса для избежания финансовых потерь.
#
# Для этого мы:
# - Построили модель, которая сможет предсказать уровень удовлетворенности сотрудника.
# - Построили модель, которая сможет предсказать то, что сотрудник уволится из компании.
#
# Мы рассматривали несколько таблиц разбитых на тренировочные и тестовые данные. Разбиение на тренировочную и тестовую выборки было в соотношении 2к1.
#
# В ходе обработки данных мы:
#
# - Перевели значения из столбцов id в индексы, и также объеденили в одну таблицу данные из тестовых выборок.
# - Избавились в данных от ошибок в столбцах dept и workload, заполнив пропуски NaN значениями.
# - Избавились от NaN значений в столбцах dept, level, workload, и заменили их наиболее встречаемыми значениями.
# - Избавились от явных дубликатов после проведенных изменений с данными.
# - Перевели значения целового признака увольнения в 0 и 1
#
# В ходе анализа данных мы получили, что:
#
# - Убедились в корректном разбиении данных на тренировочную и тестовую выборки.
# - Мультиколлинеарность между входными признаками отсутствует.
# - Больше всего сотрудников работает в отделе продаж. Мало сотрудников получали повышения за последний год.
# - В основном сотрудники работают от 2 до 6 лет, зарплата в среднем имеет значение около 30 тысяч рублей. В целом сотрудников устраивает их работа, их начальство также считает их работу приемлимой.
# - Есть малое количество сотрудников, которые по мнению начальства очень плохо выполняют свою работу. И есть небольшая часть сотрудников которые получают свыше 80 тысяч рублей.
# - Около 28% сотрудников увольняется из компании.
# - Средний уровень зарплаты Уволившихся сотрудников около 24 тысяч рублей
# - Средний уровень зарплаты Сотрудников оставшихся в компании около 38 тысяч рублей
# - Причина увольнения не зависит от того в каком отделе работает сотрудник. На причину увольнения влияет низкая зарплата, которая скорее всего связана с малым количеством задач, которые стоят перед сотрудником. Оставшиеся сотрудники как правило имеют среднюю загруженность, у тех кто уволился загруженность находилась между низкой и средней.
# - Уровень удовлетворенности сотрудника работой в компании влияет на то, уволится ли этот сотрудник. Большинство уволившихся сотрудников имеют уровень удовлетворенности меньше 0.5.
# - В основном сотрудники увольняются с уровнем Junior, проработав меньше 2 лет, не получившие повышения и имеющие малую заработную плату в районе 20 тысяч рублей.
#
#
# В ходе подготовки данных для построения обеих моделей мы:
#
# - Разделили данные на X_train, X_test, y_train, y_test.
# - Разбили наши данные на категориальные и количественные, при этом столбцы level и workload кодировали с помощью OrdinalEncoder.
#
# Для проверки качества модели, которая предсказывает уровень удовлетворенности сотрудника, мы использовали метрику SMAPE, для ее нахождения мы написали функцию.
#
# Мы выбирали среди 3 моделей с различными гиперпараметрами. Для нашей задачи лучшей моделью стала KNeighborsRegressor, которая учитывает 4 ближайших соседей, и каждая точка имеет различные веса в зависимости от расстояния. При этом лучшим методом масштабирования стал StandardScaler. Метрика SMAPE на тестовых данных показала хороший результат, равный 14.42.
#
# Для второй модели во входные признаки мы дополнительно добавили значение уровня удовлетворенности, предсказанного лучшей моделью. Значения целового признака увольнения сотрудника имели сильный дисбаланс 72% на 28%, поэтому для проверки модели, которая предсказывает увольнение сотрудника, мы использовали метрику ROC-AUC.
#
# Мы выбирали среди 3 моделей с различными гиперпараметрами. Лучшей стала DecisionTreeClassifier с параметрами max_depth=4. При этом лучшим методом масштабирования стал StandardScaler. метрика ROC-AUC на тестовой выборке показала хорошее значение 0.91.
#
# Также при сравнении наших моделей с константными моделями получили, что значения метрик наших моделей гораздо лучше, чем результат константных моделей.
#
# Компании нужно предлагать своим сотрудникам большую заработную плату. Сотрудники получив опыт, уволняются и устраиваются в другие компании с повышением уровня специальности и повышением заработной платы.
#
# Так же компании нужно решать вопрос с низкой загруженностью работой. Возможно стоит рассматривать новые направления в которых может развиваться компания, чтобы в дальнейшем подключать в них сотрудников с повышением заработной платы.
#
# Стоит рассмотреть предоставление своим сотрудникам прохождения курсов по повышению квалификации для осуществления более качественного выполнения работы и возможного карьерного роста.
